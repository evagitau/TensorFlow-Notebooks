# %% [markdown]
# <a href="https://colab.research.google.com/github/evagitau/TensorFlow-Notebooks/blob/master/Group_4_IP_Stroke_Prediction_Using_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BRAIN STROKE PREDICTION**

# %% [markdown]
# ![Brain stroke.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **PROBLEM STATEMENT**
#
# According to the World Health Organization (WHO) stroke is the 2nd leading cause of death globally, responsible for approximately 11% of total deaths, and third leading cause of disability.
#
# Brain Stroke happens when there is a blockage in the blood circulation in the brain or when a blood vessel in the brain breaks and leaks. The burst or blockage prevents blood and oxygen reaching the brain tissue.
#
# Without oxygen the tissues and cells in the brain are damaged and die in no time leading to many symptoms. Once brain cells die, they generally do not regenerate and devastating damage may occur, sometimes resulting in physical, cognitive and mental disabilities.
#
# 80% of strokes are preventable. Our project aims at evaluating the factors that may increase the chances of someone getting a stroke and building a model that can accurately predict these chances. This will help many people know the risk factors of getting a stroke and will help them prevent or avoid such risks. In retrn, many lives will be saved.

# %% [markdown]
# # **1. Defining the Question**

# %% [markdown]
# ### **Specifying the Question**

# %% [markdown]
# > What is the likelihood of a patient getting a stroke?

# %% [markdown]
# ### **Defining the Metric for Success**

# %% [markdown]
# > This research will be considered solvent when we are able to predict the likelihood of a patient getting a stroke with a model accuracy and precision of 90% and above.

# %% [markdown]
# ### **Understanding the context**

# %% [markdown]
# > A stroke is a medical condition in which poor blood flow to the brain causes cell death. There are two main types of stroke: ischemic, due to lack of blood flow, and hemorrhagic, due to bleeding. Both cause parts of the brain to stop functioning properly.
#
# > Signs and symptoms of a stroke may include an inability to move or feel on one side of the body, problems understanding or speaking, dizziness, or loss of vision to one side. Signs and symptoms often appear soon after the stroke has occurred. If symptoms last less than one or two hours, the stroke is a transient ischemic attack (TIA), also called a mini-stroke. A hemorrhagic stroke may also be associated with a severe headache. The symptoms of a stroke can be permanent. Long-term complications may include pneumonia and loss of bladder control.
#
# > The main risk factor for stroke is high blood pressure. Other risk factors include high blood cholesterol, tobacco smoking, obesity, diabetes mellitus, a previous TIA, end-stage kidney disease, and atrial fibrillation.

# %% [markdown]
# ### **Research Objectives**

# %% [markdown]
# #### **Main Objective**
#
# To predict whether a patient is likely to get a stroke.
#
# #### **Specific Objectives**
#
# 1. To find the relationship between age, BMI, glucose level and getting a stroke
# 2. To find out if hypertension and heart disease influences the likelyhood of getting a stroke
# 3. To establish whether patient's who've ever married are more likely to get a stroke than those who have never married
# 4. To identify the correlation between a patient's smoking status, place of residence and type of occupation and stroke

# %% [markdown]
# ### **Recording the Experimental Design**

# %% [markdown]
# * Defining the research question
# * Load data and preview preliminary characteristics of the dataset
# * Finding and dealing with outliers, anomalies, and missing data within the dataset
# * Perform exploratory data analysis
# * Implement the solution
# * Challenge the solution

# %% [markdown]
# ### **Relevance of the data**
#
# > This dataset is used to predict whether a patient is likely to get stroke based on the input parameters like gender, age, various diseases, and smoking status. Each row in the data provides relavant information about the patient.

# %% [markdown]
# # **2. Reading and checking the data**

# %%
#Importing the relevant libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the dataset 
stroke = pd.read_csv('/content/drive/MyDrive/healthcare-dataset-stroke-data.csv') 
stroke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Displaying the top of our dataset
stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# Displaying the bottom of our dataset
stroke.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
# Checking the shape of the dataset
stroke.shape
# Out:
# (5110, 12)

# %% [markdown]
# **Observations**
# > The dataset has 4981 rows and 12 columns.

# %%
# Checking the columns
list(stroke)
# Out:
# ['id',
#  'gender',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'ever_married',
#  'work_type',
#  'Residence_type',
#  'avg_glucose_level',
#  'bmi',
#  'smoking_status',
#  'stroke']

# %% [markdown]
# ### **Explaining the Columns**
# id: unique identifier
#
# gender: "Male", "Female" or "Other"
#
# age: age of the patient
#
# hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
#
# heart_disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
#
# ever_married: "No" or "Yes"
#
# work_type: "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
#
# Residence_type: "Rural" or "Urban"
#
# avg_glucose_level: average glucose level in blood
#
# bmi: body mass index
#
# smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*. "Unknown" means that the information is unavailable for this patient
#
# stroke: 1 if the patient had a stroke or 0 if not

# %%
# checking the general information about the dataset
stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# **Observations**
# > From the output, the dataset has some null values on the bmi column. All other columns do not have any null values and each column has the appropriate datatype.

# %% [markdown]
# # **3. External Data Source Validation**

# %% [markdown]
# > This was extracted from Kaggle open source.

# %% [markdown]
# # **4. Data Cleaning**

# %% [markdown]
# ### Checking for duplicates

# %%
# Checking if we have duplicates in the dataset
stroke.duplicated().any()
# Out:
# False

# %% [markdown]
# **Observations**
# > There are no any duplicated values in the dataset.

# %% [markdown]
# ### Checking missing values

# %%
# Checking if our dataset has missing values
print(stroke.isnull().any())
# Out:
# id                   False
# gender               False
# age                  False
# hypertension         False
# heart_disease        False
# ever_married         False
# work_type            False
# Residence_type       False
# avg_glucose_level    False
# bmi                   True
# smoking_status       False
# stroke               False
# dtype: bool

# %%
# Checking the total number of missing values
print(stroke.isnull().sum())
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# **Observations**
# > Our dataset has a total of 201 missing values in the bmi column.

# %% [markdown]
# ### Removing missing values

# %%
# We will drop the missing values from our dataset and assign the new dataset the variable stroke1

stroke1 = stroke.dropna()
stroke1
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# 5           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 5104       children          Rural             103.08  18.6          Unknown
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5104       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [4909 rows x 12 columns]

# %% [markdown]
# **Observations**
# > The new dataframe has 4909 rows and 12 columns

# %%
# Checking if there are any missing values in the new dataframe
stroke1.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# **Observations**
# > All the missing values have been dropped.

# %% [markdown]
# ### Checking for Outliers

# %%
# We will check for outliers in the numerical variables in our dataset
# age, avg_glucose_level and bmi
#
fig, ax = plt.subplots(1,3, figsize=(20,8))
fig.suptitle('Boxplots')
sns.boxplot(data=stroke1, y = 'age', ax=ax[0])
ax[0].set_title('Boxplot of Patient age')
sns.boxplot(data=stroke1, y = 'avg_glucose_level', ax=ax[1], color = 'green')
ax[1].set_title('Box Plot of Patient average glucose level')
sns.boxplot(data=stroke1, y = 'bmi', ax=ax[2], color = 'yellow')
ax[2].set_title('Box Plot of Patient Body Mass Index')
plt.show()

# %% [markdown]
# **Observations**
# > The output of the boxplots show that there are outliers. We will go ahead and check how many records of outliers we have and decide whether to remove them or use the data as is.

# %%
# Calculating the interquantile ranges for our data
#
Q1 = stroke1.quantile(0.25)
Q3 = stroke1.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# id                   36615.0
# age                     35.0
# hypertension             0.0
# heart_disease            0.0
# avg_glucose_level       36.5
# bmi                      9.6
# stroke                   0.0
# dtype: float64

# %%
# We could also calculate the IQR for our 3 variables of interest
# Calculating the interquatile ranges for the 3 variables in order to check for anomalies
# IQR for age
q1_age = stroke1['age'].quantile(0.25)
q3_age = stroke1['age'].quantile(0.75)

iqr_age = q3_age - q1_age
print(iqr_age)

# IQR for patient's average glucose level
q1_agl = stroke1['avg_glucose_level'].quantile(0.25)
q3_agl = stroke1['avg_glucose_level'].quantile(0.75)

iqr_agl = q3_agl - q1_agl
print(iqr_agl)

# IQR for patient's bmi
q1_bmi = stroke1['bmi'].quantile(0.25)
q3_bmi = stroke1['bmi'].quantile(0.75)

iqr_bmi = q3_bmi - q1_bmi
print(iqr_bmi)
# Out:
# 35.0
# 36.5
# 9.600000000000001

# %% [markdown]
# **Observations**
# > The output shows that there are 35, 36.5 and 9.6 records that are outside the interquatile ranges in the variables, age, average glucose level and bmi respectively. This data is useful in our reasearch and will therefore not be removed.

# %% [markdown]
# ### Checking distictive values

# %%
# Looking for unique values
stroke1.nunique()
# Out:
# id                   4909
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3852
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %% [markdown]
# ### Dropping unnecessary columns

# %%
# We will drop the id column since it is not relevant to our research
stroke1.drop('id', axis = 1, inplace = True)
stroke1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
# 5    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1
# 5          Urban             186.21  29.0  formerly smoked       1

# %% [markdown]
# # **5. Exploratory Data Analysis**

# %% [markdown]
# ## Univariate Analysis

# %%
# Checking the descriptive statistics of our dataset
stroke1.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4909.000000   4909.000000    4909.000000        4909.000000
# mean     42.865374      0.091872       0.049501         105.305150
# std      22.555115      0.288875       0.216934          44.424341
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.070000
# 50%      44.000000      0.000000       0.000000          91.680000
# 75%      60.000000      0.000000       0.000000         113.570000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  4909.000000
# mean     28.893237     0.042575
# std       7.854067     0.201917
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %% [markdown]
# **Observations**
#
# > The output of this summary shows the total number of rows, the mean value, the standard deviation of the data, the min and max values of the data, the 25th, 50th and 75th percentile of the data per each column with numerical values.

# %%
# Checking the unique values in our categorical variables
stroke_cat = stroke1[['gender', 'hypertension', 'heart_disease', 'ever_married','work_type', 'Residence_type', 
                 'smoking_status', 'stroke']]

for i in stroke_cat.columns:
    print(stroke_cat[i].unique())
# Out:
# ['Male' 'Female' 'Other']
# [0 1]
# [1 0]
# ['Yes' 'No']
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# ['Urban' 'Rural']
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']
# [1 0]

# %% [markdown]
# **Observations**
# > All the unique categories for the categorical data are displayed.

# %%
# Displaying the total number for each value of the categorical variable
for i in stroke_cat:
  print(stroke_cat[i].value_counts())
# Out:
# Female    2897
# Male      2011
# Other        1
# Name: gender, dtype: int64
# 0    4458
# 1     451
# Name: hypertension, dtype: int64
# 0    4666
# 1     243
# Name: heart_disease, dtype: int64
# Yes    3204
# No     1705
# Name: ever_married, dtype: int64
# Private          2811
# Self-employed     775
# children          671
# Govt_job          630
# Never_worked       22
# Name: work_type, dtype: int64
# Urban    2490
# Rural    2419
# Name: Residence_type, dtype: int64
# never smoked       1852
# Unknown            1483
# formerly smoked     837
# smokes              737
# Name: smoking_status, dtype: int64
# 0    4700
# 1     209
# Name: stroke, dtype: int64

# %% [markdown]
# **Observations**
# > The output shows the total number of values for each categorical variable

# %%
# Checking the distribution of patients age and BMI using histogram
#
fig,ax=plt.subplots(1,2,figsize=(20,10))
stroke1['age'].plot.hist(ax=ax[0],bins=10,edgecolor='black',color='blue')
ax[0].set_title('Age Distribution')
ax[0].set_xlabel('Age of Patient')
x1=list(range(0,95,10))
ax[0].set_xticks(x1)
stroke1['bmi'].plot.hist(ax=ax[1],color='green',bins=10,edgecolor='black')
ax[1].set_title('Distribution of BMI')
ax[1].set_xlabel('BMI of Patient')
x2=list(range(0,75,10))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# **Observations**
# > The output of the two histograms show that the distribution of the patient's age and BMI are symmetrical. This means that the data has a normal ditribution.

# %%
# Checking the distribution of patients average glucose level using a distribution plot
#
sns.set(rc={'figure.figsize':(8,8)})
s = sns.kdeplot(stroke1['avg_glucose_level'],shade=True)
s.set_title('Distribution of Average Glucose Level')
# Out:
# Text(0.5, 1.0, 'Distribution of Average Glucose Level')

# %% [markdown]
# **Observations**
# > The output shows that the distribution of the patient's average glucose level is not symmetrical. The distribution is skewed toward the right.

# %%
# Using bar charts to show the distribution of the patients with hypertension 
# and those with heart disease
#
fig,ax=plt.subplots(1,2,figsize=(20,10))
stroke1['hypertension'].value_counts().plot.bar(rot=0, ax=ax[0])
ax[0].set_title('Patients with hypertension')
ax[0].set_xlabel('Hypertension')
stroke1['heart_disease'].value_counts().plot.bar(rot=0, ax=ax[1], color='yellow')
ax[1].set_title('Patients with heart disease')
ax[1].set_xlabel('Heart Disease')
plt.show()

# %% [markdown]
# **Observation**
# >The number of patients with hypertention is higher than those without and the number of patients with heart disease is higher than those without as well.

# %%
# Pie chart showing the percentage number of patients per gender

fig = plt.figure(figsize=(25,10))

colors = ['green', 'orange', 'black']
stroke1['gender'].value_counts().plot.pie(colors=colors, autopct='%1.1f%%', shadow=False)
plt.title('Gender of Patient')
# Out:
# Text(0.5, 1.0, 'Gender of Patient')

# %% [markdown]
# **Observation**
# >The number of female patients is higher than that of male patients.

# %%
# A bar graph for checking if a patient has ever been married
#
stroke1['ever_married'].value_counts().plot.bar(rot=45, figsize=(12,7), color='maroon')
plt.title('Patient Marital Status')
plt.xlabel('Ever Married')
plt.ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# **Observation**
# >The number of patients who have ever been married is higher than those who have never been married

# %%
# Pie chart showing the percentage number of patients per work type

fig = plt.figure(figsize=(25,10))

colors = ['red', 'orange', 'pink', 'yellow', 'navy']
stroke1['work_type'].value_counts().plot.pie(colors=colors, autopct='%1.1f%%', shadow=False)
plt.title('Patients per work type')
# Out:
# Text(0.5, 1.0, 'Patients per work type')

# %% [markdown]
# **Observations**
# > The output shows that the highest number of surveyed patients are in the private sector and the least number of surveyed patients are those who have never worked.

# %%
# Checking a bar chart distribution for Smoking status of patients

stroke1['smoking_status'].value_counts().plot.bar(rot =45,figsize=(15,7), color= 'green')
plt.xlabel("Smoking Status")
plt.ylabel("Count")
plt.title("Smoking Status of the Patient ")
plt.show()

# %% [markdown]
# **Observations**
#
# > The number of patients who have never smoked is higher than that of patients who are former smokers and those who are smokers.

# %%
# Bar chart for patients who have had stroke before

stroke1['stroke'].value_counts().plot.bar(figsize=(12,7))
plt.xlabel("Stroke")
plt.ylabel("Count")
plt.title("Patients who have heard Stroke")
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# **Observations**
# > The number of patients who have not had stroke before is higher than those who have suffered from stroke.

# %% [markdown]
# ## Bivariate Analysis

# %%
# We will start by previewing our dataset
stroke1.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
# 5    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1
# 5          Urban             186.21  29.0  formerly smoked       1

# %%
sns.pairplot(stroke1)
plt.show()

# %% [markdown]
# **Observations**
# > The pairplot shows the correlation between different variables.

# %%
# Comparing the marital status of patients to their work type
fig = plt.figure(figsize=(14,7))
sns.countplot(x = 'work_type', hue='ever_married',data=stroke1)
plt.xticks(rotation=60)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %% [markdown]
# **Observations**
# > The output shows that the number of patients who have ever been married is higher than those who have never been married across all job sectors with the highest number being in the private sector.

# %%
# Checking which gender is most Likely to have hypertension
stroke1.groupby('gender')['hypertension'].value_counts().unstack(level=0).plot(kind='bar', stacked='True', figsize=(15,8))
labels = stroke1.groupby('gender')['hypertension'].value_counts(normalize=True)
print(labels)
plt.xticks(rotation = 45)
plt.xlabel("hypertension")
plt.ylabel("Frequency")
plt.title(" Gender Vs having hypertension")
plt.show()
# Out:
# gender  hypertension
# Female  0               0.913359
#         1               0.086641
# Male    0               0.900547
#         1               0.099453
# Other   0               1.000000
# Name: hypertension, dtype: float64

# %% [markdown]
# **Observations**
# > The output shows that the number of patients with hypertension is smaller than that of the patients without hypertension. It also shows that the male patients with hypertension are fewer than female patients with hypertension.

# %%
# Checking which gender is was highly affected by stroke before
stroke1.groupby('gender')['stroke'].value_counts().unstack(level=0).plot(kind='bar', stacked='True', figsize=(15,8))
labels = stroke1.groupby('gender')['stroke'].value_counts(normalize=False)
print(labels)
plt.xticks(rotation = 45)
plt.xlabel("Stroke")
plt.ylabel("Frequency")
plt.title(" Gender Vs having a Stroke")
plt.show()
# Out:
# gender  stroke
# Female  0         2777
#         1          120
# Male    0         1922
#         1           89
# Other   0            1
# Name: stroke, dtype: int64

# %% [markdown]
# **Observations**
# > The output shows that the number of patients without stroke is higher than that of the patients with stroke. It also shows that the number of female patients with stroke is higher than that of male patients.

# %%
# Checking which gender is most Likely to smoke
stroke1.groupby('gender')['smoking_status'].value_counts().unstack(level=0).plot(kind='bar', stacked='True', figsize=(15,8))
labels = stroke1.groupby('gender')['smoking_status'].value_counts(normalize=True)
print(labels)
plt.xticks(rotation = 45)
plt.xlabel("smoking_status")
plt.ylabel("Frequency")
plt.title(" Gender Vs Smoking Status")
plt.show()
# Out:
# gender  smoking_status
# Female  never smoked       0.415257
#         Unknown            0.279945
#         formerly smoked    0.158095
#         smokes             0.146703
# Male    Unknown            0.334162
#         never smoked       0.322725
#         formerly smoked    0.187966
#         smokes             0.155147
# Other   formerly smoked    1.000000
# Name: smoking_status, dtype: float64

# %% [markdown]
# **Observations**
# > The number of female patients who have never smoked is higher than that of male patients. Female patients who smoke are also more than their male counterparts.

# %%
# Checking which gender has the highest number of patients who have ever been married
stroke1.groupby('gender')['ever_married'].value_counts().unstack(level=0).plot(kind='bar', stacked='True', figsize=(15,8))
labels = stroke1.groupby('gender')['ever_married'].value_counts(normalize=True)
print(labels)
plt.xticks(rotation = 45)
plt.xlabel("ever_married")
plt.ylabel("Frequency")
plt.title(" Gender Vs Married Status")
plt.show()
# Out:
# gender  ever_married
# Female  Yes             0.667242
#         No              0.332758
# Male    Yes             0.632024
#         No              0.367976
# Other   No              1.000000
# Name: ever_married, dtype: float64

# %%
# Checking if the heart disease influences the chances of one getting a stroke

fig,ax=plt.subplots(1,2,figsize=(16,8))

sns.countplot(x = 'hypertension', hue='stroke',data=stroke1,ax=ax[0])
ax[0].set_title('Hypertension vs stroke')

sns.countplot(x = 'heart_disease',hue='stroke',data=stroke1,ax=ax[1])
ax[1].set_title('Heart Disease vs Stroke')

for ax in fig.axes:
  plt.sca(ax)
  plt.xticks(rotation=60)

plt.show()

# %%
# Checking which residence type has the highest number of stroke patients
Residence = stroke1.groupby(stroke1['Residence_type'])['stroke'].sum()
colors = ['green', 'skyblue']
Residence.plot(kind='pie', autopct='%1.1f%%', title='Residence area of people who had stroke', figsize=(20,10), colors = colors)

# %% [markdown]
# **Observation**
# > The output shows the patients with stroke were more in the urban areas than in the rural residence.

# %%
# Ploting a bar graph to show age distribution per each gender
#
fig = plt.figure(figsize=(15,7))
w = sns.barplot(data= stroke1, x = 'gender', y = 'age', color='yellow')
w.set_title('Distribution of age against gender')
plt.show()

# %% [markdown]
# **Observation**
# > The output shows the average age of female patients is higher than that of male patients and others.

# %%
#Relationship between residence, work type and stroke

pd.crosstab([stroke1.Residence_type, stroke1.stroke]
            ,stroke1.work_type, margins=True).style.background_gradient(cmap='Pastel1_r')
# Out:
# <style type="text/css">
# #T_af4dc_row0_col0, #T_af4dc_row0_col2, #T_af4dc_row0_col4, #T_af4dc_row0_col5, #T_af4dc_row2_col0, #T_af4dc_row2_col2, #T_af4dc_row2_col3, #T_af4dc_row2_col4, #T_af4dc_row2_col5 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# #T_af4dc_row0_col1 {
#   background-color: #e5d8bd;
#   color: #000000;
# }
# #T_af4dc_row0_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_af4dc_row1_col0, #T_af4dc_row1_col1, #T_af4dc_row1_col2, #T_af4dc_row1_col3, #T_af4dc_row1_col4, #T_af4dc_row1_col5, #T_af4dc_row3_col0, #T_af4dc_row3_col1, #T_af4dc_row3_col2, #T_af4dc_row3_col3, #T_af4dc_row3_col4, #T_af4dc_row3_col5 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_af4dc_row2_col1 {
#   background-color: #ccebc5;
#   color: #000000;
# }
# #T_af4dc_row4_col0, #T_af4dc_row4_col1, #T_af4dc_row4_col2, #T_af4dc_row4_col3, #T_af4dc_row4_col4, #T_af4dc_row4_col5 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# </style>
# <table id="T_af4dc_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >work_type</th>
#       <th class="col_heading level0 col0" >Govt_job</th>
#       <th class="col_heading level0 col1" >Never_worked</th>
#       <th class="col_heading level0 col2" >Private</th>
#       <th class="col_heading level0 col3" >Self-employed</th>
#       <th class="col_heading level0 col4" >children</th>
#       <th class="col_heading level0 col5" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Residence_type</th>
#       <th class="index_name level1" >stroke</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af4dc_level0_row0" class="row_heading level0 row0" rowspan="2">Rural</th>
#       <th id="T_af4dc_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_af4dc_row0_col0" class="data row0 col0" >289</td>
#       <td id="T_af4dc_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_af4dc_row0_col2" class="data row0 col2" >1345</td>
#       <td id="T_af4dc_row0_col3" class="data row0 col3" >346</td>
#       <td id="T_af4dc_row0_col4" class="data row0 col4" >332</td>
#       <td id="T_af4dc_row0_col5" class="data row0 col5" >2319</td>
#     </tr>
#     <tr>
#       <th id="T_af4dc_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_af4dc_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_af4dc_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_af4dc_row1_col2" class="data row1 col2" >61</td>
#       <td id="T_af4dc_row1_col3" class="data row1 col3" >25</td>
#       <td id="T_af4dc_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_af4dc_row1_col5" class="data row1 col5" >100</td>
#     </tr>
#     <tr>
#       <th id="T_af4dc_level0_row2" class="row_heading level0 row2" rowspan="2">Urban</th>
#       <th id="T_af4dc_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_af4dc_row2_col0" class="data row2 col0" >313</td>
#       <td id="T_af4dc_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_af4dc_row2_col2" class="data row2 col2" >1339</td>
#       <td id="T_af4dc_row2_col3" class="data row2 col3" >376</td>
#       <td id="T_af4dc_row2_col4" class="data row2 col4" >338</td>
#       <td id="T_af4dc_row2_col5" class="data row2 col5" >2381</td>
#     </tr>
#     <tr>
#       <th id="T_af4dc_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_af4dc_row3_col0" class="data row3 col0" >15</td>
#       <td id="T_af4dc_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_af4dc_row3_col2" class="data row3 col2" >66</td>
#       <td id="T_af4dc_row3_col3" class="data row3 col3" >28</td>
#       <td id="T_af4dc_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_af4dc_row3_col5" class="data row3 col5" >109</td>
#     </tr>
#     <tr>
#       <th id="T_af4dc_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_af4dc_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_af4dc_row4_col0" class="data row4 col0" >630</td>
#       <td id="T_af4dc_row4_col1" class="data row4 col1" >22</td>
#       <td id="T_af4dc_row4_col2" class="data row4 col2" >2811</td>
#       <td id="T_af4dc_row4_col3" class="data row4 col3" >775</td>
#       <td id="T_af4dc_row4_col4" class="data row4 col4" >671</td>
#       <td id="T_af4dc_row4_col5" class="data row4 col5" >4909</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observations**
#
# > From the output, more women have had stroke compared to men. We also see that people working in the private sector have a high change to get a stroke.

# %%
# How does marital status and smoking status affect stroke?

pd.crosstab([stroke1.ever_married,stroke1.stroke]
            ,stroke1.smoking_status,margins=True).style.background_gradient(cmap='Pastel1_r')
# Out:
# <style type="text/css">
# #T_dcbfb_row0_col0, #T_dcbfb_row2_col4 {
#   background-color: #decbe4;
#   color: #000000;
# }
# #T_dcbfb_row0_col1, #T_dcbfb_row0_col3 {
#   background-color: #fddaec;
#   color: #000000;
# }
# #T_dcbfb_row0_col2 {
#   background-color: #e5d8bd;
#   color: #000000;
# }
# #T_dcbfb_row0_col4, #T_dcbfb_row2_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_dcbfb_row1_col0, #T_dcbfb_row1_col1, #T_dcbfb_row1_col2, #T_dcbfb_row1_col3, #T_dcbfb_row1_col4, #T_dcbfb_row3_col0, #T_dcbfb_row3_col1, #T_dcbfb_row3_col2, #T_dcbfb_row3_col3, #T_dcbfb_row3_col4 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_dcbfb_row2_col1, #T_dcbfb_row2_col2, #T_dcbfb_row2_col3 {
#   background-color: #ccebc5;
#   color: #000000;
# }
# #T_dcbfb_row4_col0, #T_dcbfb_row4_col1, #T_dcbfb_row4_col2, #T_dcbfb_row4_col3, #T_dcbfb_row4_col4 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# </style>
# <table id="T_dcbfb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >smoking_status</th>
#       <th class="col_heading level0 col0" >Unknown</th>
#       <th class="col_heading level0 col1" >formerly smoked</th>
#       <th class="col_heading level0 col2" >never smoked</th>
#       <th class="col_heading level0 col3" >smokes</th>
#       <th class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ever_married</th>
#       <th class="index_name level1" >stroke</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcbfb_level0_row0" class="row_heading level0 row0" rowspan="2">No</th>
#       <th id="T_dcbfb_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_dcbfb_row0_col0" class="data row0 col0" >875</td>
#       <td id="T_dcbfb_row0_col1" class="data row0 col1" >133</td>
#       <td id="T_dcbfb_row0_col2" class="data row0 col2" >510</td>
#       <td id="T_dcbfb_row0_col3" class="data row0 col3" >164</td>
#       <td id="T_dcbfb_row0_col4" class="data row0 col4" >1682</td>
#     </tr>
#     <tr>
#       <th id="T_dcbfb_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_dcbfb_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_dcbfb_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_dcbfb_row1_col2" class="data row1 col2" >14</td>
#       <td id="T_dcbfb_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_dcbfb_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_dcbfb_level0_row2" class="row_heading level0 row2" rowspan="2">Yes</th>
#       <th id="T_dcbfb_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_dcbfb_row2_col0" class="data row2 col0" >579</td>
#       <td id="T_dcbfb_row2_col1" class="data row2 col1" >647</td>
#       <td id="T_dcbfb_row2_col2" class="data row2 col2" >1258</td>
#       <td id="T_dcbfb_row2_col3" class="data row2 col3" >534</td>
#       <td id="T_dcbfb_row2_col4" class="data row2 col4" >3018</td>
#     </tr>
#     <tr>
#       <th id="T_dcbfb_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_dcbfb_row3_col0" class="data row3 col0" >26</td>
#       <td id="T_dcbfb_row3_col1" class="data row3 col1" >54</td>
#       <td id="T_dcbfb_row3_col2" class="data row3 col2" >70</td>
#       <td id="T_dcbfb_row3_col3" class="data row3 col3" >36</td>
#       <td id="T_dcbfb_row3_col4" class="data row3 col4" >186</td>
#     </tr>
#     <tr>
#       <th id="T_dcbfb_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_dcbfb_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_dcbfb_row4_col0" class="data row4 col0" >1483</td>
#       <td id="T_dcbfb_row4_col1" class="data row4 col1" >837</td>
#       <td id="T_dcbfb_row4_col2" class="data row4 col2" >1852</td>
#       <td id="T_dcbfb_row4_col3" class="data row4 col3" >737</td>
#       <td id="T_dcbfb_row4_col4" class="data row4 col4" >4909</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observations**
#
# > From the output, people who have ever been married had stroke more than those who have never been married. We also see that people who have never smoked for both the ever married and those who have never been married had higher chances of stroke.

# %%
# Distribution of the ages of stroke patients across the different genders
stroke_age = stroke1.loc[stroke1['stroke']== 1].reset_index()
stroke_age["male_age"]=stroke_age[stroke_age["gender"]=="Male"]["age"]
stroke_age["female_age"]=stroke_age[stroke_age["gender"]=="Female"]["age"]
stroke_age[["male_age","female_age"]].plot(kind="hist", bins=20, figsize=(15,7), title="Stroke Ages")
plt.xlabel('Ages')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# **Observation**
# > The number of female patients with stroke is higher than that of male patients. The distribution also shows that chances of getting a stroke increases with age.

# %%
#Checking for correlation between our variables
stroke1.corr()
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.274425       0.257123           0.235838
# hypertension       0.274425      1.000000       0.115991           0.180543
# heart_disease      0.257123      0.115991       1.000000           0.154525
# avg_glucose_level  0.235838      0.180543       0.154525           1.000000
# bmi                0.333398      0.167811       0.041357           0.175502
# stroke             0.232331      0.142515       0.137938           0.138936
#
#                         bmi    stroke
# age                0.333398  0.232331
# hypertension       0.167811  0.142515
# heart_disease      0.041357  0.137938
# avg_glucose_level  0.175502  0.138936
# bmi                1.000000  0.042374
# stroke             0.042374  1.000000

# %%
# Heat map
plt.figure(figsize=(15,7))
sns.heatmap(stroke1.corr(), annot= True,)

# %% [markdown]
# **Observations**
#
# From the observation, there is no any high correlation between stroke and other variables.
#
# There is a small positive correlation between stroke and Age, Hypertension, Heart Disease, Average Glucose Level.
#
# Small positive correlation between Age and Stroke, Hypertension, Heart Disease, Average Glucose Level, BMI.
#
# Small positive correlation between Smoking Status and Marital Status, Occupation Type and BMI.
#
# Medium positive correlation between Age and Occupation Type.
#
# Medium negative correlation between Age and Marital Status.

# %% [markdown]
# # **6. Implementing the Solution**

# %% [markdown]
# ### **Encoding**

# %%
# Converting categorical values to numerical 
# importing LabelEncoder for categorical variables with binary values 
from sklearn.preprocessing import LabelEncoder

# instantiate labelencoder object
le = LabelEncoder()

# apply le on categorical feature columns
categorical_cols = ['gender', 'ever_married', 'Residence_type']
stroke1[categorical_cols] = stroke1[categorical_cols].apply(lambda col: le.fit_transform(col))
stroke1.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#    gender   age  hypertension  heart_disease  ever_married      work_type  \
# 0       1  67.0             0              1             1        Private
# 2       1  80.0             0              1             1        Private
# 3       0  49.0             0              0             1        Private
# 4       0  79.0             1              0             1  Self-employed
# 5       1  81.0             0              0             1        Private
#
#    Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0               1             228.69  36.6  formerly smoked       1
# 2               0             105.92  32.5     never smoked       1
# 3               1             171.23  34.4           smokes       1
# 4               0             174.12  24.0     never smoked       1
# 5               1             186.21  29.0  formerly smoked       1

# %% [markdown]
# **Observations**
#
# The data has been transformed into numerical as follows:
#
# gender:
# > 1 = male, 2 = female
#
# ever married:
# > 1 = Yes, 0 = No
#
# Residence type:
# > 1 = urban, 0 = rural

# %%
# Encoding categorical data with more than 2 values using get_dummies
stroke2 = pd.get_dummies(stroke1, columns=['work_type','smoking_status'], drop_first=False)
stroke2.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  Residence_type  \
# 0       1  67.0             0              1             1               1
# 2       1  80.0             0              1             1               0
# 3       0  49.0             0              0             1               1
# 4       0  79.0             1              0             1               0
# 5       1  81.0             0              0             1               1
#
#    avg_glucose_level   bmi  stroke  work_type_Govt_job  \
# 0             228.69  36.6       1                   0
# 2             105.92  32.5       1                   0
# 3             171.23  34.4       1                   0
# 4             174.12  24.0       1                   0
# 5             186.21  29.0       1                   0
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# 2                       0                  1                        0
# 3                       0                  1                        0
# 4                       0                  0                        1
# 5                       0                  1                        0
#
#    work_type_children  smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                   0                       0                               1
# 2                   0                       0                               0
# 3                   0                       0                               0
# 4                   0                       0                               0
# 5                   0                       0                               1
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            0                      0
# 2                            1                      0
# 3                            0                      1
# 4                            1                      0
# 5                            0                      0

# %% [markdown]
# **Observations**
# > Our dataset has received additional dummy variables. This is because the 'work_type' and 'smoking_status' variables have been split into different variables each representing a specific category.

# %%
# Previewing the shape of our encoded dataset
stroke2.shape
# Out:
# (4909, 18)

# %% [markdown]
# **Observations**
# > After encoding, our dataset now has 4909 rows and 18 columns.

# %% [markdown]
# ### **Splitting the data**

# %%
# Splitting the dataset into train and test using train test split
# We will use a test size of 25%
#
from sklearn.model_selection import train_test_split

X=stroke2.drop('stroke',axis=1)
y=stroke2['stroke']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=0)

# %%
# Checking the shapes of our feature variables
X.shape, X_train.shape, X_test.shape
# Out:
# ((4909, 17), (3681, 17), (1228, 17))

# %% [markdown]
# **Observations**
# > Our feature variables have 4909 rows and 17 columns, X_train has 3681 rows and 17 columns and X_test has 1228 rows and 17 columns.

# %%
# Checking the shapes of our target variable
y.shape, y_train.shape, y_test.shape
# Out:
# ((4909,), (3681,), (1228,))

# %% [markdown]
# **Observations**
# > Our target variable have 4909 rows y_train has 3681 rowsy_test has 1228 rows.

# %% [markdown]
# ### **Normalization of data**

# %%
# We will normalize our data by using StandardScaler
# Initialize the scaler
#
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fitting the scaler
scaler.fit(X_train)

# Applying the transformation to the data
X_train = scaler.transform(X_train)

X_test = scaler.transform(X_test)

# %% [markdown]
# ### **Training our Model**

# %%
# Checking if the counts of our target variables to see if the classes are balanced
#
y_train.value_counts()
# Out:
# 0    3521
# 1     160
# Name: stroke, dtype: int64

# %% [markdown]
# **Observations**
#
# > The output shows that 3521 patients do not have stroke while only 160 of them have stroke. This means that our target variable is imbalanced.

# %%
# Before training the model, we will firts start by removing the class imbalance
# import SMOTE oversampling
from collections import Counter
from imblearn.over_sampling import SMOTE

# summarize class distribution
print("Before oversampling: ",Counter(y_train))

# define oversampling strategy
SMOTE = SMOTE()

# fit and apply the transform
X_train_SMOTE, y_train_SMOTE = SMOTE.fit_resample(X_train, y_train)

# summarize class distribution
print("After oversampling: ",Counter(y_train_SMOTE))
# Out:
# Before oversampling:  Counter({0: 3521, 1: 160})
# After oversampling:  Counter({1: 3521, 0: 3521})

# %% [markdown]
# **Observations**
#
# > After applying SMOTE oversampling, the classes have balanced with 3521 records each.

# %%
# Now that we have removed the imbalance, we will train our model using Tensorflow 
# algorithim
#
import tensorflow as tf
tf.random.set_seed(0)

# We will use the sequential model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
                             ])

model.compile(
    loss=tf.keras.losses.binary_crossentropy,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.03),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
    ])   

# Modeling
# We will now fit the X_train and y_train into our algorithm 
# and save our mode under the variable history
#
history = model.fit(X_train_SMOTE, y_train_SMOTE, epochs = 10)
# Out:
# Epoch 1/10
# 221/221 [==============================] - 2s 4ms/step - loss: 0.4903 - accuracy: 0.7802 - precision: 0.7482 - recall: 0.8446
# Epoch 2/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.3856 - accuracy: 0.8314 - precision: 0.7816 - recall: 0.9199
# Epoch 3/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.3495 - accuracy: 0.8461 - precision: 0.8006 - recall: 0.9216
# Epoch 4/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.3140 - accuracy: 0.8699 - precision: 0.8247 - recall: 0.9395
# Epoch 5/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.3001 - accuracy: 0.8844 - precision: 0.8421 - recall: 0.9463
# Epoch 6/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.2656 - accuracy: 0.8997 - precision: 0.8599 - recall: 0.9551
# Epoch 7/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.2426 - accuracy: 0.9090 - precision: 0.8729 - recall: 0.9574
# Epoch 8/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.2309 - accuracy: 0.9124 - precision: 0.8781 - recall: 0.9577
# Epoch 9/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.2261 - accuracy: 0.9155 - precision: 0.8824 - recall: 0.9588
# Epoch 10/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.2081 - accuracy: 0.9230 - precision: 0.8888 - recall: 0.9671

# %% [markdown]
# **Observations**
# > The loss function decreases as the training increases, accuracy, precision and recall increases as the model continuous to train.

# %%
# We then visualize the metrics to see how the model is performing
#
plt.figure(figsize=(16, 8))
plt.plot(history.history['loss'], label = 'Loss')
plt.plot(history.history['accuracy'], label = 'Accuracy')
plt.plot(history.history['precision'], label = 'Precision')
plt.plot(history.history['recall'], label = 'Recall')
plt.title('Evaluation metrics', size=20)
plt.xlabel('Epoch', size=14)
plt.legend()

# %% [markdown]
# **Observations**
# > From the output, we note that the loss function decreases while the accuracy, recall and Precision increase as the model training increases. This shows that our model performance is good.

# %% [markdown]
# ### **Prediction and Evaluation**

# %%
# Using our model to make predictions
#
pred = model.predict(X_test)
pred[:30]
# Out:
# 39/39 [==============================] - 0s 2ms/step
# array([[5.0898890e-12],
#        [2.9624054e-09],
#        [1.5491889e-03],
#        [7.9680145e-01],
#        [4.3352187e-02],
#        [6.9822039e-04],
#        [9.3982083e-01],
#        [3.6007627e-10],
#        [3.0604799e-31],
#        [0.0000000e+00],
#        [4.1714945e-01],
#        [0.0000000e+00],
#        [5.4792245e-27],
#        [1.5114226e-38],
#        [4.0374902e-01],
#        [0.0000000e+00],
#        [2.7040346e-02],
#        [1.7190019e-04],
#        [2.8479821e-03],
#        [0.0000000e+00],
#        [3.9614366e-21],
#        [9.2266474e-22],
#        [1.6364887e-09],
#        [0.0000000e+00],
#        [9.3982083e-01],
#        [1.0665851e-03],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.1272265e-03],
#        [0.0000000e+00]], dtype=float32)

# %% [markdown]
# **Observations**
# > The model outputs the predicted probabilities, we first need to transform them back to class labels before calculating the classification metrics.

# %%
# extract the predicted class labels
y_pred = np.where(pred > 0.5, 1, 0)

# %%
# Evaluating the model
#
from sklearn.metrics import classification_report, confusion_matrix

confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

# Checking the classification report
print(classification_report(y_test, y_pred))
# Out:
# [[1032  147]
#  [  34   15]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92      1179
#            1       0.09      0.31      0.14        49
#
#     accuracy                           0.85      1228
#    macro avg       0.53      0.59      0.53      1228
# weighted avg       0.93      0.85      0.89      1228

# %% [markdown]
# **Observations**
# > The results from the confusion matrix tell us that 1032 and 15 are the number of correct predictions while 34 and 147 are the number of incorrect predictions. The model performance has a precision score of 97%, recall of 88%, f1-score of 92% and accuracy of 85%.

# %% [markdown]
# # **7. Challenging the solution**

# %% [markdown]
# We will now challenge our solution by using a different optimizer and also by using a different algorithm to see if the model's accurancy and precision scores will be better.

# %%
# Now that we have removed the imbalance, we will train our model using Tensorflow 
#
import tensorflow as tf
tf.random.set_seed(0)

# We will use the sequential model

model_new = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
                             ])

model_new.compile(
    loss=tf.keras.losses.binary_crossentropy,
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.03),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
    ])   

new = model_new.fit(X_train_SMOTE, y_train_SMOTE, epochs = 10)
# Out:
# Epoch 1/10
# 221/221 [==============================] - 2s 3ms/step - loss: 0.5224 - accuracy: 0.7515 - precision: 0.7228 - recall: 0.8160
# Epoch 2/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.4241 - accuracy: 0.8050 - precision: 0.7840 - recall: 0.8421
# Epoch 3/10
# 221/221 [==============================] - 1s 3ms/step - loss: 0.3915 - accuracy: 0.8265 - precision: 0.7957 - recall: 0.8784
# Epoch 4/10
# 221/221 [==============================] - 1s 3ms/step - loss: 0.3692 - accuracy: 0.8388 - precision: 0.8094 - recall: 0.8864
# Epoch 5/10
# 221/221 [==============================] - 1s 4ms/step - loss: 0.3473 - accuracy: 0.8502 - precision: 0.8194 - recall: 0.8983
# Epoch 6/10
# 221/221 [==============================] - 1s 3ms/step - loss: 0.3271 - accuracy: 0.8596 - precision: 0.8268 - recall: 0.9097
# Epoch 7/10
# 221/221 [==============================] - 1s 3ms/step - loss: 0.3109 - accuracy: 0.8661 - precision: 0.8392 - recall: 0.9057
# Epoch 8/10
# 221/221 [==============================] - 1s 3ms/step - loss: 0.2879 - accuracy: 0.8789 - precision: 0.8461 - recall: 0.9262
# Epoch 9/10
# 221/221 [==============================] - 1s 3ms/step - loss: 0.2659 - accuracy: 0.8921 - precision: 0.8590 - recall: 0.9381
# Epoch 10/10
# 221/221 [==============================] - 1s 3ms/step - loss: 0.2519 - accuracy: 0.8978 - precision: 0.8671 - recall: 0.9395

# %%
plt.figure(figsize=(16, 8))
plt.plot(new.history['loss'], label = 'Loss')
plt.plot(new.history['accuracy'], label = 'Accuracy')
plt.plot(new.history['precision'], label = 'Precision')
plt.plot(new.history['recall'], label = 'Recall')
plt.title('Evaluation metrics', size=20)
plt.xlabel('Epoch', size=14)
plt.legend()

# %% [markdown]
# **Observations**
# > The loss function decreases as the training increases, accuracy, precision and recall increases as the model continuous to train. However, the perfoemance of the model is lower than that attained when using Adam as the optimizer.

# %%
# Using our model to make predictions
#
pred = model_new.predict(X_test)

# extract the predicted class labels
pred_new = np.where(pred > 0.5, 1, 0)
# Out:
# 39/39 [==============================] - 0s 2ms/step

# %%
# Evaluating the model
#
from sklearn.metrics import classification_report, confusion_matrix

confusion_matrix = confusion_matrix(y_test, pred_new)
print(confusion_matrix)

# Looking at the classification report
print(classification_report(y_test, pred_new))
# Out:
# [[930 249]
#  [ 29  20]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87      1179
#            1       0.07      0.41      0.13        49
#
#     accuracy                           0.77      1228
#    macro avg       0.52      0.60      0.50      1228
# weighted avg       0.93      0.77      0.84      1228

# %% [markdown]
# **Observations**
# > The results from the confusion matrix tell us that 930 and 249 are the number of correct predictions while 29 and 249 are the number of incorrect predictions. The model performance has a precision score of 97%, recall of 79%, f1-score of 87% and accuracy of 77%. This means that the model's performance is poorer than when we use Adam as the optimizer.

# %%
# We will now use SVM algorithim to predict and check the performance of the model
# import SVM libraries 
#
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

model=SVC()
clf = model.fit(X_train_SMOTE, y_train_SMOTE)
pred_svc = clf.predict(X_test)

print("ROC AUC score for oversampled SMOTE data: ", roc_auc_score(y_test, pred_svc))
confusion_matrix = confusion_matrix(y_test, pred_svc)
print(confusion_matrix)
print(classification_report(y_test, pred_svc))
# Out:
# ROC AUC score for oversampled SMOTE data:  0.6184158141628153
# [[977 202]
#  [ 29  20]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89      1179
#            1       0.09      0.41      0.15        49
#
#     accuracy                           0.81      1228
#    macro avg       0.53      0.62      0.52      1228
# weighted avg       0.94      0.81      0.86      1228

# %% [markdown]
# **Observations**
# > The output tells us that 977 and 20 are the number of correct predictions while 29 and 202 are the number of incorrect predictions. The model performance has a precision score of 97%, recall of 83%, f1-score of 89% and accuracy of 81%. This means that the model's performance is better than when we use Tensorflow algorithm using Stochastic Gradient Descent optimizer but lower than when we use Tensorflow algorithm using Adam as the optimizer.

# %% [markdown]
# # **8. Follow up questions**

# %% [markdown]
# ### a). Did we have the right data?
#
# The given data was relevant in answering our research question as we were able to effectively investigate the given variables and gain insights on the characteristics of stroke patients in the given population.

# %% [markdown]
# ### b). Do we need other data to answer our question?
# In order to properly understand and predict the chances of one getting a stroke, we could also investigate the characteristics of more variables of stroke patients such as ther health conditions associated with stroke patients, lifestyle of stroke patients and health care accessibility.

# %% [markdown]
# ### c). Did we have the right question?
# Our question was right because it enabled us have correct objectives that enabled us to create a model that would predict the chances of a patient getting a stroke.

# %% [markdown]
# # **9. Conclusion**
#
# Although investigating the characteristics of more variables of stroke patients such as health and lifestyle conditions associated with stroke patients would have brought more perspective to our reasearch, the given data was still sufficient in answering our research question and meet the set objectives. This is because we were able to effectively investigate the given variables and build a model using Neural Network Tensorflow algorithm, that would correctly predict the chances of a patient getting a stroke with an accuracy of 97% and a precision of 85%.
